# %%
from alphatest import backtest, util

data_path = r"C:\Users\qwane\Documents\git\alphatest\data\binance_spot"

# %%
at = backtest(data_path=data_path)
cs = util.cross_sectional(valid_df=at.valid_df)
# Out:
# Backtesting parameters:
# Annual days: 365, Daily ticks: 1
# Trading fee (%): 0.025%
# Risk free return (%): 3.0%
# Data path: C:\Users\qwane\Documents\git\alphatest\data\binance_spot
# Crypto benchmarks: ['BTC']
# Stock benchmarks: ['VOO', 'GLD']

# %%
df_returns = at.get_data("returns")
df_returns
# Out:
#                                 BTC       ETH       XRP      DOGE       SOL  \
# time
# 2017-08-17 00:00:00+00:00       NaN       NaN       NaN       NaN       NaN
# 2017-08-18 00:00:00+00:00 -0.041238 -0.026623       NaN       NaN       NaN
# 2017-08-19 00:00:00+00:00  0.007694 -0.010376       NaN       NaN       NaN
# 2017-08-20 00:00:00+00:00 -0.012969  0.028153       NaN       NaN       NaN
# 2017-08-21 00:00:00+00:00 -0.017201  0.080876       NaN       NaN       NaN
# ...                             ...       ...       ...       ...       ...
# 2025-09-27 00:00:00+00:00 -0.000069 -0.003437  0.007616 -0.007185 -0.008335
# 2025-09-28 00:00:00+00:00  0.023059  0.030803  0.022355  0.028513  0.036223
# 2025-09-29 00:00:00+00:00  0.019151  0.017602  0.004429 -0.010828  0.009107
# 2025-09-30 00:00:00+00:00 -0.002301 -0.016588 -0.011562 -0.007880 -0.019130
# 2025-10-01 00:00:00+00:00  0.037274  0.044761  0.033336  0.061735  0.056881
#
#                                 ADA       BNB       TRX
# time
# 2017-08-17 00:00:00+00:00       NaN       NaN       NaN
# 2017-08-18 00:00:00+00:00       NaN       NaN       NaN
# 2017-08-19 00:00:00+00:00       NaN       NaN       NaN
# 2017-08-20 00:00:00+00:00       NaN       NaN       NaN
# 2017-08-21 00:00:00+00:00       NaN       NaN       NaN
# ...                             ...       ...       ...
# 2025-09-27 00:00:00+00:00 -0.013891  0.007962 -0.005025
# 2025-09-28 00:00:00+00:00  0.035472  0.025360 -0.002674
# 2025-09-29 00:00:00+00:00 -0.003092  0.037039  0.003277
# 2025-09-30 00:00:00+00:00  0.001365 -0.020664 -0.009501
# 2025-10-01 00:00:00+00:00  0.049802  0.015667  0.024281
#
# [2968 rows x 8 columns]

# %%
strategy_return = at.run(df_returns)
# Out:
# Backtesting parameters:
# Annual days: 365, Daily ticks: 1
# Trading fee (%): 0.025%
# Risk free return (%): 3.0%
# Data path: C:\Users\qwane\Documents\git\alphatest\data\binance_spot
# Crypto benchmarks: ['BTC']
# Stock benchmarks: ['VOO', 'GLD']
# Scale final: True
#
#                  Metrics Strategy    VOO    GLD    BTC
# 0           Sharpe Ratio    -0.39   0.53   0.76   0.69
# 1          Profit Factor     1.01   1.16   1.18   1.16
# 2                   CAGR    -0.33   0.13   0.14   0.50
# 3       Maximum Drawdown    -1.00  -0.34  -0.22  -0.83
# 4  Annualized Volatility     0.91   0.19   0.15   0.69
# 5          Sortino Ratio    -0.54   0.64   1.09   0.92
# 6           Calmar Ratio    -0.36   0.30   0.50   0.57
# 7     Daily Turnover (%)   138.31   0.00   0.00   0.00
# 8    Long/Short position     0.08   1.00   1.00   1.00

# %%
at.fee = 0.00025
at.run(df_returns.apply(cs.neutralize,axis=1))
# Out:
# Backtesting parameters:
# Annual days: 365, Daily ticks: 1
# Trading fee (%): 0.025%
# Risk free return (%): 3.0%
# Data path: C:\Users\qwane\Documents\git\alphatest\data\binance_spot
# Crypto benchmarks: ['BTC']
# Stock benchmarks: ['VOO', 'GLD']
# Scale final: True
#
#                  Metrics Strategy    VOO    GLD    BTC
# 0           Sharpe Ratio     0.31   0.53   0.76   0.69
# 1          Profit Factor     1.14   1.16   1.18   1.16
# 2                   CAGR     0.20   0.13   0.14   0.50
# 3       Maximum Drawdown    -0.83  -0.34  -0.22  -0.83
# 4  Annualized Volatility     0.53   0.19   0.15   0.69
# 5          Sortino Ratio     0.36   0.64   1.09   0.92
# 6           Calmar Ratio     0.20   0.30   0.50   0.57
# 7     Daily Turnover (%)   135.15   0.00   0.00   0.00
# 8    Long/Short position     0.00   1.00   1.00   1.00
# {'annual_return': np.float64(0.1957069736407091),
#  'annual_vol': np.float64(0.5349962709411218),
#  'sharpe': np.float64(0.3097348199254005),
#  'profit_factor': np.float64(1.1358022895260158),
#  'sortino': np.float64(0.3646046950777262),
#  'drawdown': time
#  2017-08-18 00:00:00+00:00    0.000000
#  2017-08-19 00:00:00+00:00   -0.009535
#  2017-08-20 00:00:00+00:00   -0.030395
#  2017-08-21 00:00:00+00:00    0.000000
#  2017-08-22 00:00:00+00:00   -0.024352
#                                 ...
#  2025-09-27 00:00:00+00:00   -0.470295
#  2025-09-28 00:00:00+00:00   -0.472372
#  2025-09-29 00:00:00+00:00   -0.472447
#  2025-09-30 00:00:00+00:00   -0.475313
#  2025-10-01 00:00:00+00:00   -0.473196
#  Name: strategy, Length: 2967, dtype: float64,
#  'max_drawdown': np.float64(-0.8293930404616994),
#  'calmar': np.float64(0.1997930601738167),
#  'returns': time
#  2017-08-18 00:00:00+00:00    0.000000
#  2017-08-19 00:00:00+00:00   -0.009535
#  2017-08-20 00:00:00+00:00   -0.021061
#  2017-08-21 00:00:00+00:00    0.049039
#  2017-08-22 00:00:00+00:00   -0.024352
#                                 ...
#  2025-09-27 00:00:00+00:00   -0.005782
#  2025-09-28 00:00:00+00:00   -0.003920
#  2025-09-29 00:00:00+00:00   -0.000143
#  2025-09-30 00:00:00+00:00   -0.005433
#  2025-10-01 00:00:00+00:00    0.004034
#  Name: strategy, Length: 2967, dtype: float64,
#  'turnover': np.float64(135.14609359029694),
#  'long_short': np.float64(3.541215508298795e-18)}

# %%
at.get_distribution(df_returns)

# %%
at.run(abs(df_returns[["BTC"]]))
# Out:
# Backtesting parameters:
# Annual days: 365, Daily ticks: 1
# Trading fee (%): 0.025%
# Risk free return (%): 3.0%
# Data path: C:\Users\qwane\Documents\git\alphatest\data\binance_spot
# Crypto benchmarks: ['BTC']
# Stock benchmarks: ['VOO', 'GLD']
# Scale final: True
#
#                  Metrics Strategy    VOO    GLD    BTC
# 0           Sharpe Ratio     0.70   0.53   0.76   0.69
# 1          Profit Factor     1.16   1.16   1.18   1.16
# 2                   CAGR     0.51   0.13   0.14   0.50
# 3       Maximum Drawdown    -0.83  -0.34  -0.22  -0.83
# 4  Annualized Volatility     0.69   0.19   0.15   0.69
# 5          Sortino Ratio     0.94   0.64   1.09   0.92
# 6           Calmar Ratio     0.58   0.30   0.50   0.57
# 7     Daily Turnover (%)     0.00   0.00   0.00   0.00
# 8    Long/Short position     1.00   1.00   1.00   1.00
# {'annual_return': np.float64(0.5119059915331206),
#  'annual_vol': np.float64(0.6902686217611974),
#  'sharpe': np.float64(0.6981426887166817),
#  'profit_factor': np.float64(1.1616039419457842),
#  'sortino': np.float64(0.9379511743131009),
#  'drawdown': time
#  2017-08-18 00:00:00+00:00    0.000000
#  2017-08-19 00:00:00+00:00    0.000000
#  2017-08-20 00:00:00+00:00   -0.012969
#  2017-08-21 00:00:00+00:00   -0.029947
#  2017-08-22 00:00:00+00:00   -0.024150
#                                 ...
#  2025-09-27 00:00:00+00:00   -0.110867
#  2025-09-28 00:00:00+00:00   -0.090364
#  2025-09-29 00:00:00+00:00   -0.072944
#  2025-09-30 00:00:00+00:00   -0.075077
#  2025-10-01 00:00:00+00:00   -0.040602
#  Name: strategy, Length: 2967, dtype: float64,
#  'max_drawdown': np.float64(-0.8318705353076464),
#  'calmar': np.float64(0.5793040756695388),
#  'returns': time
#  2017-08-18 00:00:00+00:00    0.000000
#  2017-08-19 00:00:00+00:00    0.007694
#  2017-08-20 00:00:00+00:00   -0.012969
#  2017-08-21 00:00:00+00:00   -0.017201
#  2017-08-22 00:00:00+00:00    0.005976
#                                 ...
#  2025-09-27 00:00:00+00:00   -0.000069
#  2025-09-28 00:00:00+00:00    0.023059
#  2025-09-29 00:00:00+00:00    0.019151
#  2025-09-30 00:00:00+00:00   -0.002301
#  2025-10-01 00:00:00+00:00    0.037274
#  Name: strategy, Length: 2967, dtype: float64,
#  'turnover': np.float64(0.0),
#  'long_short': np.float64(1.0)}
