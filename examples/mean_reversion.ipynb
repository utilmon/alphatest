# %%
from alphatest import backtest, util

data_path = r"C:\Users\qwane\Documents\git\alphatest\data\binance_spot"

# %%
at = backtest(data_path=data_path)

# %%
df_returns = at.get_data("returns")
df_returns
# Out:
#                                 BTC       ETH       XRP      DOGE       SOL  \
# time
# 2024-05-07 00:00:00+00:00       NaN       NaN       NaN       NaN       NaN
# 2024-05-08 00:00:00+00:00 -0.017959 -0.010473 -0.014109 -0.045003 -0.039519
# 2024-05-09 00:00:00+00:00  0.030738  0.020853  0.007349  0.062552  0.073076
# 2024-05-10 00:00:00+00:00 -0.036053 -0.041578 -0.035899 -0.054599 -0.042997
# 2024-05-11 00:00:00+00:00  0.000428  0.000845  0.007368 -0.005768 -0.004041
# ...                             ...       ...       ...       ...       ...
# 2025-09-14 00:00:00+00:00 -0.005610 -0.013295 -0.029301 -0.039464 -0.010809
# 2025-09-15 00:00:00+00:00  0.000709 -0.017537 -0.010238 -0.034717 -0.022731
# 2025-09-16 00:00:00+00:00  0.012477 -0.004963  0.013581  0.006112  0.011310
# 2025-09-17 00:00:00+00:00 -0.002923  0.019825  0.015308  0.046712  0.033255
# 2025-09-18 00:00:00+00:00  0.002979 -0.002540 -0.004442 -0.016917  0.006984
#
#                                 ADA       BNB       TRX
# time
# 2024-05-07 00:00:00+00:00       NaN       NaN       NaN
# 2024-05-08 00:00:00+00:00  0.023561  0.020989  0.020081
# 2024-05-09 00:00:00+00:00  0.025896  0.013931  0.026601
# 2024-05-10 00:00:00+00:00 -0.033657 -0.018767  0.009588
# 2024-05-11 00:00:00+00:00 -0.019871  0.011270 -0.008084
# ...                             ...       ...       ...
# 2025-09-14 00:00:00+00:00 -0.044652 -0.007679 -0.003432
# 2025-09-15 00:00:00+00:00 -0.027818 -0.007372 -0.010617
# 2025-09-16 00:00:00+00:00  0.019810  0.039111 -0.007251
# 2025-09-17 00:00:00+00:00  0.038055  0.035923  0.002921
# 2025-09-18 00:00:00+00:00  0.007989 -0.007384  0.019516
#
# [500 rows x 8 columns]

# %%
strategy_return = at.run(df_returns)
print(strategy_return)
# Out:
#                  Metrics  Strategy    VOO    GLD    BTC
# 0           Sharpe Ratio      1.21   1.27   2.88   1.21
# 1                   CAGR      0.81   0.30   0.62   0.58
# 2       Maximum Drawdown     -0.42  -0.19  -0.08  -0.28
# 3  Annualized Volatility      0.64   0.21   0.21   0.46
# 4          Sortino Ratio      1.71   1.59   4.44   1.97
# 5           Calmar Ratio      1.86   1.41   7.32   1.97
# 6    Annual Turnover (%)  48531.50   0.00   0.00   0.00
# 7    Long/Short position      0.07   1.00   1.00   1.00
# time
# 2024-05-08 00:00:00+00:00   -0.000250
# 2024-05-09 00:00:00+00:00   -0.027188
# 2024-05-10 00:00:00+00:00   -0.037550
# 2024-05-11 00:00:00+00:00    0.001673
# 2024-05-12 00:00:00+00:00    0.001153
#                                ...
# 2025-09-14 00:00:00+00:00   -0.027614
# 2025-09-15 00:00:00+00:00    0.022449
# 2025-09-16 00:00:00+00:00   -0.010121
# 2025-09-17 00:00:00+00:00    0.024855
# 2025-09-18 00:00:00+00:00   -0.003407
# Length: 499, dtype: float64
