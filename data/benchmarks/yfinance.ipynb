# %%
import yfinance as yf

# %%
sp500 = yf.download("QQQ")
# Out:
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['QQQ']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')

# %%
sp500
# Out:
# Empty DataFrame
# Columns: [(Adj Close, ^GSPC), (Close, ^GSPC), (High, ^GSPC), (Low, ^GSPC), (Open, ^GSPC), (Volume, ^GSPC)]
# Index: []
